# %% [markdown]
# Introduction to Jupyter Notebook

# %%
print("Hey this is just testing of Jupyter Notebook")
# Out:
# Hey this is just testing of Jupyter Notebook

# %%
import numpy as np
arr = np.array([10, 20, 30])
print(arr)
arr.sum()
arr.mean()
# Out:
# [10 20 30]
# np.float64(20.0)

# %%
arr.shape
# Out:
# (3,)

# %% [markdown]
# <!-- Broadcasting -->
# arr + 5

# %%
twoDarr = np.array([
                [1, 2, 3], 
                [4, 5, 6]
])
oneDarr = np.array([10, 20, 30])
twoDarr + oneDarr
twoDarr.sum()
# Out:
# np.int64(21)

# %%
tDarr = np.array([
            [1, 2, 3], 
            [4, 5, 6]
])
anotherTDarr = np.array([
        [1, 2, 3], 
        [4, 5, 6]
])
tDarr + anotherTDarr
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])
